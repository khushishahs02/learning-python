# %%
#first we will load the data

# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %%
df = pd.read_csv(r'anime.csv') 
#format to read the cscv file on python
#you have to provide a path in the brackets, but as it in the
#same folder, we will directly write the name of the file

# %%
#The .head() method is one of the most frequently used
#  functions in Pandas. Its primary purpose is to give you
#  a quick "snapshot" of your dataset without loading 
# thousands of rows into your display, which could crash
#  your notebook or make it impossible to read.

#By default, df.head() returns the first 5 rows of a DataFrame. 
# It is essentially a "preview" tool used immediately after 
# loading data to verify that headers, data types, and values
#  look correct.

df.head(n=5) #if we leave it blank default is set to 5
#if we pass a negative number it will return all rows except last n
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %%
#feature extraction is the process of transforming raw 
# data into a set of numerical features that can be processed
# while still accurately describing the original data set.

# if we want to get episode count of each anime
#but it is not explicitly mentioned there, so we have to extract it

#observe : there are brackets surrounding the episode

# %%
def extract_episodes(txt) :
    #start extraction from ( and end with )
    check = False
    data = "" #initialize the string
    for i in txt :
        if i == ")" :
            check = False
            return data
        if check == True :
            data += i
        if i == "(":
            check = True

# %%
#apply the function to all the tiles and make a new column named episodes
df["Episodes"] = df["Title"].apply(extract_episodes)

# %%
df["Episodes"] = df["Episodes"].str.replace(" eps","")

# %%
df['Episodes'] = df["Episodes"].astype(int)

# %%
display(df)
# Out:
#     Rank                                              Title  Score  Episodes
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04        51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04         1
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04       148
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04        13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03        13
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03         2
# ...

# %%
#second feature to be extracted

#make a new column for time stamp
df.loc[1]["Title"]

#bracket close ke baad hi hai
# Out:
# 'Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473,707 members'

# %%
def extract_timestamp(txt) :
    #there are 18 characters for time to be extracted
    check = False
    data = ""
    for i in range(len(txt)) :
        if txt[i] == ")" :
            for j in range(i+1,i+20) :
              data += txt[j]
            return data

# %%
df["Time Stamp"] = df["Title"].apply(extract_timestamp)
df.head()
# Out:
#    Rank                                              Title  Score  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
#
#             Time Stamp Months
# 0  Apr 2009 - Jul 2010   None
# 1  Apr 2011 - Sep 2011   None
# 2  Oct 2022 - Dec 2022   None
# 3  Apr 2015 - Mar 2016   None
# 4  Apr 2019 - Jul 2019   None

# %%
#extract total months from the time stamp
#splits the data in two parts by -
#datetime.strptime(....,%d %Y) is the parser which looks for month and years
#it turns the string into actual date time that the python actually understands

from dateutil.relativedelta import relativedelta
from datetime import datetime

def calculate_total_months(period):
    try:
        start_str, end_str = period.split(' - ')
        start_date = datetime.strptime(start_str, '%b %Y')
        end_date = datetime.strptime(end_str, '%b %Y')
        r = relativedelta(end_date, start_date) #calculates the exact difference between the two dates
        return r.years * 12 + r.months + 1  # +1 to include the starting month
    except:
        return None
    
    #try/except if code has some unknown data then it wont crash and return null

df['Months'] = df['Time Stamp'].apply(calculate_total_months)

# %%
df.head()
# Out:
#    Rank                                              Title  Score  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
#
#             Time Stamp  Months
# 0  Apr 2009 - Jul 2010      16
# 1  Apr 2011 - Sep 2011       6
# 2  Oct 2022 - Dec 2022       3
# 3  Apr 2015 - Mar 2016      12
# 4  Apr 2019 - Jul 2019       4

# %%
#the anime that has highest score
df[df['Score']== df['Score'].max()]['Title']
# Out:
# 0    Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# Name: Title, dtype: str

# %%
#top 5 highest scoring anime

df.sort_values(by = 'Score',ascending = False).head()
# Out:
#    Rank                                              Title  Score  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
#
#             Time Stamp  Months
# 0  Apr 2009 - Jul 2010      16
# 1  Apr 2011 - Sep 2011       6
# 2  Oct 2022 - Dec 2022       3
# 3  Apr 2015 - Mar 2016      12
# 4  Apr 2019 - Jul 2019       4

# %%
# highest episode count

df[df['Episodes'] == df['Episodes'].max()]
# Out:
#     Rank                                              Title  Score  Episodes  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94       201
#
#              Time Stamp  Months
# 15  Apr 2006 - Mar 2010      48

# %%
#anime with top 5 anime count
df.sort_values(by = 'Episodes', ascending = False).head()
# Out:
#     Rank                                              Title  Score  Episodes  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94       201
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04       148
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02       110
# 42    43  Hajime no IppoTV (75 eps)Oct 2000 - Mar 200255...   8.76        75
# 24    25  MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...   8.87        74
#
#              Time Stamp  Months
# 15  Apr 2006 - Mar 2010      48
# 7   Oct 2011 - Sep 2014      36
# 11  Jan 1988 - Mar 1997     111
# 42  Oct 2000 - Mar 2002      18
# 24  Apr 2004 - Sep 2005      18

# %%
import re

#to extract clean title name from the title
def get_title_name(text) :
    return text.split('(')[0].strip()

# %% [markdown]
# # function for title

# %%
#
